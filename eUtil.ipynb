# %% [markdown]
# <h1>Getting data files from NCBI SRA with eUtils</h1>
# <p>First, ensure that BioPython is installed.</p>
# <pre> sudo /home/.../anaconda3/bin/pip install biopython</pre>

# %%
from Bio import Entrez 
import xmltodict
import pandas as pd
import numpy as np

# %%
#to avoid anaonymous requests, adjust as needed
Entrez.email = "my@email.eu"

# %%
database="sra"
search_terms="estrogen receptor chip-seq AND homo sapiens[Organism]"
maxhits=200
handle=Entrez.esearch(db=database,term=search_terms,retmax=maxhits)

# %%
records = Entrez.read(handle)

# %%
identifiers = records['IdList']
identifiers
# Out:
# ['5772180', '5772179', '5772178', '5772177', '5772176', '5679946', '5679945', '5679944', '5679943', '5679942', '5679941', '5679940', '5679939', '5679938', '5679937', '5026291', '5026290', '5026289', '5026288', '5026287', '5026286', '5026285', '5026284', '5026283', '5026282', '5026281', '4463046', '4463045', '4463044', '4463043', '4463042', '4463041', '4463040', '4463039', '4463038', '4463037', '4463036', '4463035', '4463034', '4463033', '4463032', '4463031', '4463030', '4463029', '4417855', '4417854', '4417853', '4417852', '4417851', '4417850', '4417849', '4417848', '4417847', '4417846', '4417845', '4417844', '4417843', '4417842', '4417841', '4417840', '4417839', '4417838', '4417837', '4417836', '4417835', '4417834', '4417833', '4417832', '4285995', '4285994', '4285993', '4285992', '4285991', '4285990', '4285989', '4285988', '4285987', '4285986', '4175998', '4175997', '4175996', '4175995', '4175994', '4175993', '4175992', '4175991', '4175990', '4175989', '4175988', '4175987', '4148037', '4148036', '4148035', '4148034', '4148033', '4148032', '4148031', '4148030', '4148029', '4148028', '4148027', '4148026', '4148025', '4148024', '4148023', '4148022', '4148021', '4148020', '4148019', '4148018', '4148017', '4148016', '4148015', '4148014', '4148013', '4148012', '4148011', '4148010', '4148009', '4148008', '4148007', '4148006', '4148005', '4148004', '4148003', '4148002', '4148001', '4148000', '4147999', '4147998', '4147997', '4147996', '4147995', '4147994', '4147993', '4147992', '4147991', '4147990', '4147989', '4162881', '4162880', '4162879', '4162878', '4162877', '4162876', '4162875', '4162874', '4162873', '4162872', '4162871', '4162870', '4162868', '4162866', '4162864', '4162862', '4162860', '4162858', '4162856', '4162854', '4162852', '4162850', '4162848', '4152748', '4152747', '4152746', '4152745', '4152744', '4152743', '4152742', '4152741', '4152740', '4152739', '4152738', '4152737', '4152736', '4152735', '4152734', '4124032', '4124031', '4124030', '4124029', '4124028', '4124027', '4124026', '4124025', '4124024', '4124023', '4124022', '3676536', '3676535', '3676534', '3676533', '3676532', '3676531', '3676530', '3676529', '3676528', '3676527', '3676526', '3676525']

# %%
handle = Entrez.efetch(db=database, id=identifiers, retmax="200", retmode="text")

# %%
#ecord = Entrez.read(handle,validate=False
#records=Entrez.parse(handle)
#for record in records:
#rint(handle.read())
text=handle.read()

# %%
import xmltodict

# %%
doc=xmltodict.parse(text)

# %% [markdown]
# <h2>Parsing the output of SRA/eUtils</h2>
# <p>The <tt>Entrez.efetch</tt> command returns XML, which the <tt>xmltodict</tt> package transforms into a hierarchical
# Python dictionary. The top element is <tt>EXPERIMENT_PACKAGE_SET</tt>. Underneath that there is a list of
# <tt>EXPERIMENT_PACKAGE</tt> objects. There should be one such <tt>EXPERIMENT_PACKAGE</tt> for each ChIP-seq experiment that SRA returns.</p>
# <p>The following function extracts information from an individual <tt>EXPERIMENT_PACKAGE</tt> and puts the info
#     into a row of a pandas dataframe.</p>

# %%
def parse_experiment_package(ep,i,df):
    #experiment=ep['EXPERIMENT']
    for item in ep:
        if (item=='EXPERIMENT'):
            experiment=ep[item]
            experiment_alias = experiment['@alias']
            experiment_accession= experiment['@accession']
            title=experiment['TITLE']
            studyref=experiment['STUDY_REF'] # this is an ordered dict
            study_accession=studyref['@accession']
            study_refname=studyref['@refname']
            #print(study_accession,study_refname)
            design=experiment['DESIGN']# this is an ordered dict
            sample_descriptor=design['SAMPLE_DESCRIPTOR']
            sample_accession=sample_descriptor['@accession']
            library_descriptor=design['LIBRARY_DESCRIPTOR']# this is an ordered dict
            library_strategy=library_descriptor['LIBRARY_STRATEGY']
            library_construction=library_descriptor['LIBRARY_CONSTRUCTION_PROTOCOL']
            #print(sample_accession,library_strategy,library_construction)
            platform=experiment['PLATFORM']
            illumina=platform['ILLUMINA']
            instrument=illumina['INSTRUMENT_MODEL']
            #print(instrument)
            #experiment_links=experiment['EXPERIMENT_LINKS']
            #experiment_attributes=experiment['EXPERIMENT_ATTRIBUTES']
            submission=ep['SUBMISSION']
            submission_alias=submission['@alias']
            submission_accession=submission['@accession']
            study=ep['STUDY']
            descriptor=study['DESCRIPTOR']
            study_title=descriptor['STUDY_TITLE']
            study_type=descriptor['STUDY_TYPE']
            study_abstract=descriptor['STUDY_ABSTRACT']
            df.loc[i]=[experiment_alias,experiment_accession,title,
               study_accession,study_refname,sample_accession,library_strategy,library_construction,
               instrument,submission_alias,submission_accession,study_title,study_type,study_abstract]

# %% [markdown]
# <h2>Create a pandas dataframe to hold the results</h2>
# <p>
# We will now create a pandas dataframe to hold the results, defining columns that match those sought after in the above function.
# Not good style, refactor later on!</p>

# %%
numberOfRows=maxhits
df=pd.DataFrame(index=np.arange(0,numberOfRows),columns=('experiment_alias','experiment_accession','title',
               'study_accession','study_refname','sample_accession','library_strategy','library_construction',
               'instrument','submission_alias','submission_accession','study_title','study_type','study_abstract'))

# %%
doc2=doc['EXPERIMENT_PACKAGE_SET']
#the following gets a list of EXPERIMENT_PACKAGE objects
doc3=doc2['EXPERIMENT_PACKAGE']
i=0
for ep in doc3:
    try:
        parse_experiment_package (ep,i,df)
        i=i+1
    except:
        print("Could not parse this entry")
# Out:
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry
# Could not parse this entry

# %%
from IPython.display import display, HTML
display(df)
# Out:
#     experiment_alias experiment_accession  \
# 0         GSM3212403           SRX4284795
# 1         GSM3212402           SRX4284794
# 2         GSM3212401           SRX4284793
# 3         GSM3212400           SRX4284792
# 4         GSM3212399           SRX4284791
# 5         GSM3184880           SRX4193150
# 6         GSM3184879           SRX4193149
# 7         GSM3184878           SRX4193148
# 8         GSM3184877           SRX4193147
# 9         GSM3184876           SRX4193146
# 10        GSM3184875           SRX4193145
# 11        GSM3184874           SRX4193144
# 12        GSM3184873           SRX4193143
# 13        GSM3184872           SRX4193142
# 14        GSM3184871           SRX4193141
# 15        GSM2973404           SRX3630824
# 16        GSM2973403           SRX3630823
# 17        GSM2973402           SRX3630822
# 18        GSM2973401           SRX3630821
# 19        GSM2973400           SRX3630820
# 20        GSM2973399           SRX3630819
# 21        GSM2973398           SRX3630818
# 22        GSM2973397           SRX3630817
# 23        GSM2973396           SRX3630816
# 24        GSM2973395           SRX3630815
# 25        GSM2973394           SRX3630814
# 26        GSM2752601           SRX3123833
# 27        GSM2752600           SRX3123832
# 28        GSM2752599           SRX3123831
# 29        GSM2752598           SRX3123830
# ..               ...                  ...
# 170       GSM2476831           SRX2539936
# 171       GSM2476830           SRX2539935
# 172       GSM2476829           SRX2539934
# 173       GSM2476828           SRX2539933
# 174       GSM2476827           SRX2539932
# 175       GSM2476826           SRX2539931
# 176       GSM2476825           SRX2539930
# 177       GSM2476824           SRX2539929
# 178       GSM2476823           SRX2539928
# 179       GSM2476822           SRX2539927
# 180       GSM2476821           SRX2539926
# 181       GSM2476820           SRX2539925
# 182              NaN                  NaN
# 183              NaN                  NaN
# 184              NaN                  NaN
# 185              NaN                  NaN
# 186              NaN                  NaN
# 187              NaN                  NaN
# 188              NaN                  NaN
# 189              NaN                  NaN
# 190              NaN                  NaN
# 191              NaN                  NaN
# 192              NaN                  NaN
# 193              NaN                  NaN
# 194              NaN                  NaN
# 195              NaN                  NaN
# 196              NaN                  NaN
# 197              NaN                  NaN
# 198              NaN                  NaN
# 199              NaN                  NaN
#
#                                                  title study_accession  \
# 0    GSM3212403: T47D_YFP_noE2_HA_ChIPseq; Homo sap...       SRP151140
# 1    GSM3212402: T47D_ESR1NOP2_noE2_HA_ChIPseq; Hom...       SRP151140
# 2    GSM3212401: T47D_ESR1PCDH11X_noE2_HA_ChIPseq; ...       SRP151140
# 3    GSM3212400: T47D_ESR1YAP1_noE2_HA_ChIPseq; Hom...       SRP151140
# 4    GSM3212399: T47D_ESR1WT_noE2_HA_ChIPseq; Homo ...       SRP151140
# 5    GSM3184880: ERalpha s10 E2 ChIPSeq; Homo sapie...       SRP150236
# 6    GSM3184879: ERalpha s9 Fulv ChIPSeq; Homo sapi...       SRP150236
# 7    GSM3184878: ERalpha s8 Tam ChIPSeq; Homo sapie...       SRP150236
# 8    GSM3184877: ERalpha s7 s5942 ChIPSeq; Homo sap...       SRP150236
# 9    GSM3184876: ERalpha s6 5942 ChIPSeq; Homo sapi...       SRP150236
# 10   GSM3184875: ERalpha s5 RAD1901 ChIPSeq; Homo s...       SRP150236
# 11   GSM3184874: ERalpha s4 800 ChIPSeq; Homo sapie...       SRP150236
# 12   GSM3184873: ERalpha s3 s6545 ChIPSeq; Homo sap...       SRP150236
# 13   GSM3184872: ERalpha s2 6545 ChIPSeq; Homo sapi...       SRP150236
# 14   GSM3184871: ERalpha s1 DMSO ChIPSeq; Homo sapi...       SRP150236
# 15   GSM2973404: H3K27ac_input_8hr; Homo sapiens; C...       SRP131799
# 16   GSM2973403: H3K27ac_DMSO_8hr; Homo sapiens; Ch...       SRP131799
# 17   GSM2973402: H3K27ac_Dex_8hr; Homo sapiens; ChI...       SRP131799
# 18   GSM2973401: H3K27ac_E2_Dex_8hr; Homo sapiens; ...       SRP131799
# 19   GSM2973400: H3K27ac_E2_8hr; Homo sapiens; ChIP...       SRP131799
# 20   GSM2973399: Ishi_DMSO_ChIP_GR; Homo sapiens; C...       SRP131799
# 21   GSM2973398: Ishi_DMSO_ChIP_ER; Homo sapiens; C...       SRP131799
# 22   GSM2973397: Ishi_Dex_ChIP_GR; Homo sapiens; Ch...       SRP131799
# 23   GSM2973396: Ishi_E2_ChIP_ER; Homo sapiens; ChI...       SRP131799
# 24   GSM2973395: Ishi_Dex_E2_ChIP_GR; Homo sapiens;...       SRP131799
# 25   GSM2973394: Ishi_Dex_E2_ChIP_ER; Homo sapiens;...       SRP131799
# 26   GSM2752601: jc2929_MCF7_Input_AZD2014; Homo sa...       SRP116074
# 27   GSM2752600: jc2928_MCF7_Input_RAD001; Homo sap...       SRP116074
# 28   GSM2752599: jc2927_MCF7_Input_Veh; Homo sapien...       SRP116074
# 29   GSM2752598: jc2926_MCF7_ER_AZD2014; Homo sapie...       SRP116074
# ..                                                 ...             ...
# 170  GSM2476831: T47D-Y537S-DOXE2-TS8-MP2496; Homo ...       SRP098916
# 171  GSM2476830: T47D-Y537S-DOX-TS6-MP2496; Homo sa...       SRP098916
# 172  GSM2476829: T47D-Y537S-E2-TS7-MP2496; Homo sap...       SRP098916
# 173  GSM2476828: Y537S-DOXE2-rep2-S2-8-MP2867; Homo...       SRP098916
# 174  GSM2476827: Y537S-DOXE2-rep1-S2-7-MP2867; Homo...       SRP098916
# 175  GSM2476826: Y537S-DOXE2-SSS5-MP2498; Homo sapi...       SRP098916
# 176  GSM2476825: Y537S-DOX-rep2-S2-4-MP2867; Homo s...       SRP098916
# 177  GSM2476824: Y537S-DOX-rep1-S2-3-MP2867; Homo s...       SRP098916
# 178  GSM2476823: Y537S-DOX-SSS3-MP2498; Homo sapien...       SRP098916
# 179  GSM2476822: Y537S-E2-rep2-S2-6-MP2867; Homo sa...       SRP098916
# 180  GSM2476821: Y537S-E2-rep1-S2-5-MP2867; Homo sa...       SRP098916
# 181  GSM2476820: Y537S-E2-SSS4-MP2498; Homo sapiens...       SRP098916
# 182                                                NaN             NaN
# 183                                                NaN             NaN
# 184                                                NaN             NaN
# 185                                                NaN             NaN
# 186                                                NaN             NaN
# 187                                                NaN             NaN
# 188                                                NaN             NaN
# 189                                                NaN             NaN
# 190                                                NaN             NaN
# 191                                                NaN             NaN
# 192                                                NaN             NaN
# 193                                                NaN             NaN
# 194                                                NaN             NaN
# 195                                                NaN             NaN
# 196                                                NaN             NaN
# 197                                                NaN             NaN
# 198                                                NaN             NaN
# 199                                                NaN             NaN
#
#     study_refname sample_accession library_strategy  \
# 0       GSE116170       SRS3448952         ChIP-Seq
# 1       GSE116170       SRS3448951         ChIP-Seq
# 2       GSE116170       SRS3448950         ChIP-Seq
# 3       GSE116170       SRS3448949         ChIP-Seq
# 4       GSE116170       SRS3448967         ChIP-Seq
# 5       GSE115607       SRS3403984         ChIP-Seq
# 6       GSE115607       SRS3403986         ChIP-Seq
# 7       GSE115607       SRS3403983         ChIP-Seq
# 8       GSE115607       SRS3403982         ChIP-Seq
# 9       GSE115607       SRS3403979         ChIP-Seq
# 10      GSE115607       SRS3403980         ChIP-Seq
# 11      GSE115607       SRS3403978         ChIP-Seq
# 12      GSE115607       SRS3403976         ChIP-Seq
# 13      GSE115607       SRS3403977         ChIP-Seq
# 14      GSE115607       SRS3403981         ChIP-Seq
# 15      GSE109891       SRS2897537         ChIP-Seq
# 16      GSE109891       SRS2897536         ChIP-Seq
# 17      GSE109891       SRS2897534         ChIP-Seq
# 18      GSE109891       SRS2897535         ChIP-Seq
# 19      GSE109891       SRS2897533         ChIP-Seq
# 20      GSE109891       SRS2897532         ChIP-Seq
# 21      GSE109891       SRS2897530         ChIP-Seq
# 22      GSE109891       SRS2897531         ChIP-Seq
# 23      GSE109891       SRS2897527         ChIP-Seq
# 24      GSE109891       SRS2897529         ChIP-Seq
# 25      GSE109891       SRS2897528         ChIP-Seq
# 26      GSE103023       SRS2458192         ChIP-Seq
# 27      GSE103023       SRS2458191         ChIP-Seq
# 28      GSE103023       SRS2458190         ChIP-Seq
# 29      GSE103023       SRS2458189         ChIP-Seq
# ..            ...              ...              ...
# 170      GSE94493       SRS1959644         ChIP-Seq
# 171      GSE94493       SRS1959642         ChIP-Seq
# 172      GSE94493       SRS1959643         ChIP-Seq
# 173      GSE94493       SRS1959641         ChIP-Seq
# 174      GSE94493       SRS1959640         ChIP-Seq
# 175      GSE94493       SRS1959639         ChIP-Seq
# 176      GSE94493       SRS1959638         ChIP-Seq
# 177      GSE94493       SRS1959636         ChIP-Seq
# 178      GSE94493       SRS1959637         ChIP-Seq
# 179      GSE94493       SRS1959635         ChIP-Seq
# 180      GSE94493       SRS1959633         ChIP-Seq
# 181      GSE94493       SRS1959634         ChIP-Seq
# 182           NaN              NaN              NaN
# 183           NaN              NaN              NaN
# 184           NaN              NaN              NaN
# 185           NaN              NaN              NaN
# 186           NaN              NaN              NaN
# 187           NaN              NaN              NaN
# 188           NaN              NaN              NaN
# 189           NaN              NaN              NaN
# 190           NaN              NaN              NaN
# 191           NaN              NaN              NaN
# 192           NaN              NaN              NaN
# 193           NaN              NaN              NaN
# 194           NaN              NaN              NaN
# 195           NaN              NaN              NaN
# 196           NaN              NaN              NaN
# 197           NaN              NaN              NaN
# 198           NaN              NaN              NaN
# 199           NaN              NaN              NaN
#
#                                   library_construction           instrument  \
# 0    Cells were grown hormone-deprived media for 7 ...  Illumina HiSeq 2500
# 1    Cells were grown hormone-deprived media for 7 ...  Illumina HiSeq 2500
# 2    Cells were grown hormone-deprived media for 7 ...  Illumina HiSeq 2500
# 3    Cells were grown hormone-deprived media for 7 ...  Illumina HiSeq 2500
# 4    Cells were grown hormone-deprived media for 7 ...  Illumina HiSeq 2500
# 5    Cells were formaldehyde fixed for 15 minutes (...          NextSeq 500
# 6    Cells were formaldehyde fixed for 15 minutes (...          NextSeq 500
# 7    Cells were formaldehyde fixed for 15 minutes (...          NextSeq 500
# 8    Cells were formaldehyde fixed for 15 minutes (...          NextSeq 500
# 9    Cells were formaldehyde fixed for 15 minutes (...          NextSeq 500
# 10   Cells were formaldehyde fixed for 15 minutes (...          NextSeq 500
# 11   Cells were formaldehyde fixed for 15 minutes (...          NextSeq 500
# 12   Cells were formaldehyde fixed for 15 minutes (...          NextSeq 500
# 13   Cells were formaldehyde fixed for 15 minutes (...          NextSeq 500
# 14   Cells were formaldehyde fixed for 15 minutes (...          NextSeq 500
# 15   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 16   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 17   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 18   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 19   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 20   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 21   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 22   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 23   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 24   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 25   Cells were fixed in 1% formaldehyde for 10 min...  Illumina HiSeq 2500
# 26   Cells were crosslinked for 10min using 1% form...  Illumina HiSeq 2500
# 27   Cells were crosslinked for 10min using 1% form...  Illumina HiSeq 2500
# 28   Cells were crosslinked for 10min using 1% form...  Illumina HiSeq 2500
# 29   Cells were crosslinked for 10min using 1% form...  Illumina HiSeq 2500
# ..                                                 ...                  ...
# 170  Cell lines before ChIP were then either introd...          NextSeq 500
# 171  Cell lines before ChIP were then either introd...          NextSeq 500
# 172  Cell lines before ChIP were then either introd...          NextSeq 500
# 173  Cell lines before ChIP were then either introd...          NextSeq 500
# 174  Cell lines before ChIP were then either introd...          NextSeq 500
# 175  Cell lines before ChIP were then either introd...          NextSeq 500
# 176  Cell lines before ChIP were then either introd...          NextSeq 500
# 177  Cell lines before ChIP were then either introd...          NextSeq 500
# 178  Cell lines before ChIP were then either introd...          NextSeq 500
# 179  Cell lines before ChIP were then either introd...          NextSeq 500
# 180  Cell lines before ChIP were then either introd...          NextSeq 500
# 181  Cell lines before ChIP were then either introd...          NextSeq 500
# 182                                                NaN                  NaN
# 183                                                NaN                  NaN
# 184                                                NaN                  NaN
# 185                                                NaN                  NaN
# 186                                                NaN                  NaN
# 187                                                NaN                  NaN
# 188                                                NaN                  NaN
# 189                                                NaN                  NaN
# 190                                                NaN                  NaN
# 191                                                NaN                  NaN
# 192                                                NaN                  NaN
# 193                                                NaN                  NaN
# 194                                                NaN                  NaN
# 195                                                NaN                  NaN
# 196                                                NaN                  NaN
# 197                                                NaN                  NaN
# 198                                                NaN                  NaN
# 199                                                NaN                  NaN
#
#     submission_alias submission_accession  \
# 0     GEO: GSE116170            SRA726535
# 1     GEO: GSE116170            SRA726535
# 2     GEO: GSE116170            SRA726535
# 3     GEO: GSE116170            SRA726535
# 4     GEO: GSE116170            SRA726535
# 5     GEO: GSE115607            SRA719221
# 6     GEO: GSE115607            SRA719221
# 7     GEO: GSE115607            SRA719221
# 8     GEO: GSE115607            SRA719221
# 9     GEO: GSE115607            SRA719221
# 10    GEO: GSE115607            SRA719221
# 11    GEO: GSE115607            SRA719221
# 12    GEO: GSE115607            SRA719221
# 13    GEO: GSE115607            SRA719221
# 14    GEO: GSE115607            SRA719221
# 15    GEO: GSE109891            SRA653941
# 16    GEO: GSE109891            SRA653941
# 17    GEO: GSE109891            SRA653941
# 18    GEO: GSE109891            SRA653941
# 19    GEO: GSE109891            SRA653941
# 20    GEO: GSE109891            SRA653941
# 21    GEO: GSE109891            SRA653941
# 22    GEO: GSE109891            SRA653941
# 23    GEO: GSE109891            SRA653941
# 24    GEO: GSE109891            SRA653941
# 25    GEO: GSE109891            SRA653941
# 26    GEO: GSE103023            SRA602384
# 27    GEO: GSE103023            SRA602384
# 28    GEO: GSE103023            SRA602384
# 29    GEO: GSE103023            SRA602384
# ..               ...                  ...
# 170    GEO: GSE94493            SRA535839
# 171    GEO: GSE94493            SRA535839
# 172    GEO: GSE94493            SRA535839
# 173    GEO: GSE94493            SRA535839
# 174    GEO: GSE94493            SRA535839
# 175    GEO: GSE94493            SRA535839
# 176    GEO: GSE94493            SRA535839
# 177    GEO: GSE94493            SRA535839
# 178    GEO: GSE94493            SRA535839
# 179    GEO: GSE94493            SRA535839
# 180    GEO: GSE94493            SRA535839
# 181    GEO: GSE94493            SRA535839
# 182              NaN                  NaN
# 183              NaN                  NaN
# 184              NaN                  NaN
# 185              NaN                  NaN
# 186              NaN                  NaN
# 187              NaN                  NaN
# 188              NaN                  NaN
# 189              NaN                  NaN
# 190              NaN                  NaN
# 191              NaN                  NaN
# 192              NaN                  NaN
# 193              NaN                  NaN
# 194              NaN                  NaN
# 195              NaN                  NaN
# 196              NaN                  NaN
# 197              NaN                  NaN
# 198              NaN                  NaN
# 199              NaN                  NaN
#
#                                            study_title  \
# 0    Transcriptional properties of estrogen recepto...
# 1    Transcriptional properties of estrogen recepto...
# 2    Transcriptional properties of estrogen recepto...
# 3    Transcriptional properties of estrogen recepto...
# 4    Transcriptional properties of estrogen recepto...
# 5    ChIP-Seq analysis of estrogen deprived MCF7 ce...
# 6    ChIP-Seq analysis of estrogen deprived MCF7 ce...
# 7    ChIP-Seq analysis of estrogen deprived MCF7 ce...
# 8    ChIP-Seq analysis of estrogen deprived MCF7 ce...
# 9    ChIP-Seq analysis of estrogen deprived MCF7 ce...
# 10   ChIP-Seq analysis of estrogen deprived MCF7 ce...
# 11   ChIP-Seq analysis of estrogen deprived MCF7 ce...
# 12   ChIP-Seq analysis of estrogen deprived MCF7 ce...
# 13   ChIP-Seq analysis of estrogen deprived MCF7 ce...
# 14   ChIP-Seq analysis of estrogen deprived MCF7 ce...
# 15   Clinical and genomic crosstalk between glucoco...
# 16   Clinical and genomic crosstalk between glucoco...
# 17   Clinical and genomic crosstalk between glucoco...
# 18   Clinical and genomic crosstalk between glucoco...
# 19   Clinical and genomic crosstalk between glucoco...
# 20   Clinical and genomic crosstalk between glucoco...
# 21   Clinical and genomic crosstalk between glucoco...
# 22   Clinical and genomic crosstalk between glucoco...
# 23   Clinical and genomic crosstalk between glucoco...
# 24   Clinical and genomic crosstalk between glucoco...
# 25   Clinical and genomic crosstalk between glucoco...
# 26   Estrogen receptor ChIP-seq in response to mTOR...
# 27   Estrogen receptor ChIP-seq in response to mTOR...
# 28   Estrogen receptor ChIP-seq in response to mTOR...
# 29   Estrogen receptor ChIP-seq in response to mTOR...
# ..                                                 ...
# 170  ChIPseq and RNAseq of ER mutant breast cancer ...
# 171  ChIPseq and RNAseq of ER mutant breast cancer ...
# 172  ChIPseq and RNAseq of ER mutant breast cancer ...
# 173  ChIPseq and RNAseq of ER mutant breast cancer ...
# 174  ChIPseq and RNAseq of ER mutant breast cancer ...
# 175  ChIPseq and RNAseq of ER mutant breast cancer ...
# 176  ChIPseq and RNAseq of ER mutant breast cancer ...
# 177  ChIPseq and RNAseq of ER mutant breast cancer ...
# 178  ChIPseq and RNAseq of ER mutant breast cancer ...
# 179  ChIPseq and RNAseq of ER mutant breast cancer ...
# 180  ChIPseq and RNAseq of ER mutant breast cancer ...
# 181  ChIPseq and RNAseq of ER mutant breast cancer ...
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                             study_type  \
# 0    {'@existing_study_type': 'Other'}
# 1    {'@existing_study_type': 'Other'}
# 2    {'@existing_study_type': 'Other'}
# 3    {'@existing_study_type': 'Other'}
# 4    {'@existing_study_type': 'Other'}
# 5    {'@existing_study_type': 'Other'}
# 6    {'@existing_study_type': 'Other'}
# 7    {'@existing_study_type': 'Other'}
# 8    {'@existing_study_type': 'Other'}
# 9    {'@existing_study_type': 'Other'}
# 10   {'@existing_study_type': 'Other'}
# 11   {'@existing_study_type': 'Other'}
# 12   {'@existing_study_type': 'Other'}
# 13   {'@existing_study_type': 'Other'}
# 14   {'@existing_study_type': 'Other'}
# 15   {'@existing_study_type': 'Other'}
# 16   {'@existing_study_type': 'Other'}
# 17   {'@existing_study_type': 'Other'}
# 18   {'@existing_study_type': 'Other'}
# 19   {'@existing_study_type': 'Other'}
# 20   {'@existing_study_type': 'Other'}
# 21   {'@existing_study_type': 'Other'}
# 22   {'@existing_study_type': 'Other'}
# 23   {'@existing_study_type': 'Other'}
# 24   {'@existing_study_type': 'Other'}
# 25   {'@existing_study_type': 'Other'}
# 26   {'@existing_study_type': 'Other'}
# 27   {'@existing_study_type': 'Other'}
# 28   {'@existing_study_type': 'Other'}
# 29   {'@existing_study_type': 'Other'}
# ..                                 ...
# 170  {'@existing_study_type': 'Other'}
# 171  {'@existing_study_type': 'Other'}
# 172  {'@existing_study_type': 'Other'}
# 173  {'@existing_study_type': 'Other'}
# 174  {'@existing_study_type': 'Other'}
# 175  {'@existing_study_type': 'Other'}
# 176  {'@existing_study_type': 'Other'}
# 177  {'@existing_study_type': 'Other'}
# 178  {'@existing_study_type': 'Other'}
# 179  {'@existing_study_type': 'Other'}
# 180  {'@existing_study_type': 'Other'}
# 181  {'@existing_study_type': 'Other'}
# 182                                NaN
# 183                                NaN
# 184                                NaN
# 185                                NaN
# 186                                NaN
# 187                                NaN
# 188                                NaN
# 189                                NaN
# 190                                NaN
# 191                                NaN
# 192                                NaN
# 193                                NaN
# 194                                NaN
# 195                                NaN
# 196                                NaN
# 197                                NaN
# 198                                NaN
# 199                                NaN
#
#                                         study_abstract
# 0    RNA sequencing (RNA-seq) detects estrogen rece...
# 1    RNA sequencing (RNA-seq) detects estrogen rece...
# 2    RNA sequencing (RNA-seq) detects estrogen rece...
# 3    RNA sequencing (RNA-seq) detects estrogen rece...
# 4    RNA sequencing (RNA-seq) detects estrogen rece...
# 5    The goal of this experiment was to interrogate...
# 6    The goal of this experiment was to interrogate...
# 7    The goal of this experiment was to interrogate...
# 8    The goal of this experiment was to interrogate...
# 9    The goal of this experiment was to interrogate...
# 10   The goal of this experiment was to interrogate...
# 11   The goal of this experiment was to interrogate...
# 12   The goal of this experiment was to interrogate...
# 13   The goal of this experiment was to interrogate...
# 14   The goal of this experiment was to interrogate...
# 15   Steroid hormone receptors are simultaneously a...
# 16   Steroid hormone receptors are simultaneously a...
# 17   Steroid hormone receptors are simultaneously a...
# 18   Steroid hormone receptors are simultaneously a...
# 19   Steroid hormone receptors are simultaneously a...
# 20   Steroid hormone receptors are simultaneously a...
# 21   Steroid hormone receptors are simultaneously a...
# 22   Steroid hormone receptors are simultaneously a...
# 23   Steroid hormone receptors are simultaneously a...
# 24   Steroid hormone receptors are simultaneously a...
# 25   Steroid hormone receptors are simultaneously a...
# 26   We have used ChIP-seq to profile binding of th...
# 27   We have used ChIP-seq to profile binding of th...
# 28   We have used ChIP-seq to profile binding of th...
# 29   We have used ChIP-seq to profile binding of th...
# ..                                                 ...
# 170  We performed several extensive phenotypic, gen...
# 171  We performed several extensive phenotypic, gen...
# 172  We performed several extensive phenotypic, gen...
# 173  We performed several extensive phenotypic, gen...
# 174  We performed several extensive phenotypic, gen...
# 175  We performed several extensive phenotypic, gen...
# 176  We performed several extensive phenotypic, gen...
# 177  We performed several extensive phenotypic, gen...
# 178  We performed several extensive phenotypic, gen...
# 179  We performed several extensive phenotypic, gen...
# 180  We performed several extensive phenotypic, gen...
# 181  We performed several extensive phenotypic, gen...
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
# [200 rows x 14 columns]
